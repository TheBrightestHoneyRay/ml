# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Dropout, Flatten, MaxPooling2D, BatchNormalization, MaxPool1D
from tensorflow.keras.optimizers import Adam
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import seaborn as sns #statistical data visualization

# %%
#read the data
transactions = pd.read_csv('creditcard.csv') 
transactions.head()
transactions.shape
# Out:
# (284807, 31)

# %%
#check number of fraud and non-fraud transactions
transactions['Class'].value_counts()
fraud = transactions[transactions['Class'] == 1] 
valid = transactions[transactions['Class'] == 0] 
print('Fraud Transactions: {}'.format(len(fraud))) 
print('Valid Transactions: {}'.format(len(valid))) 
valid = fraud.sample(fraud.shape[0])
my_balanced_data = fraud.append(valid, ignore_index = True)
my_balanced_data
# Out:
# Fraud Transactions: 492
# Valid Transactions: 284315
#          Time        V1        V2        V3        V4        V5        V6  \
# 0       406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 1       472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 2      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 3      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 4      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  102318.0 -1.020632  1.496959 -4.490937  1.836727  0.627318 -2.735569
# 980   32686.0  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 981  155359.0 -1.067713  5.262312 -8.438567  7.316487  0.008254 -2.125936
# 982  158638.0 -5.976119 -7.196980 -5.388316  5.104799  4.676533 -5.566870
# 983  148028.0 -1.053840  4.362801 -6.023534  5.304534  1.480738 -2.193821
#
#            V7        V8        V9  ...       V21       V22       V23  \
# 0   -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 1    0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
# 2    0.562320 -0.399147 -0.238253  ... -0.294166 -0.932391  0.172726
# 3   -3.496197 -0.248778 -0.247768  ...  0.573574  0.176968 -0.436207
# 4    1.713445 -0.496358 -1.282858  ... -0.379068 -0.704181 -0.656805
# ..        ...       ...       ...  ...       ...       ...       ...
# 979 -1.546274  0.459822 -0.682741  ...  0.773631  0.860618 -0.304666
# 980 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
# 981 -3.307036  1.869838 -4.522584  ...  0.547790 -0.491960  0.055914
# 982 -4.291180  0.876531 -1.075478  ...  1.459369 -0.136262  0.848177
# 983 -1.530817  0.626857 -4.037021  ...  0.397954 -0.945402 -0.376138
#
#           V24       V25       V26       V27       V28  Amount  Class
# 0    0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 1   -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 2   -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 3   -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 4   -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
# ..        ...       ...       ...       ...       ...     ...    ...
# 979 -0.155500  0.412166 -0.220080  0.392338 -0.020089   22.04      1
# 980  0.187613  0.368708 -0.132474  0.576561  0.309843    0.00      1
# 981 -1.145369  0.068951  0.535055  0.539263  0.124255    0.77      1
# 982 -0.269916 -1.095060 -0.710905  0.565846 -1.034107  296.00      1
# 983 -0.220480  0.264003  0.048935  0.847220  0.531932    0.00      1
#
# [984 rows x 31 columns]

# %%
#use train_test_split function to split transactions into training and test sets
x = my_balanced_data.drop(['Class'], axis = 1) # get features
y = my_balanced_data["Class"] 
#use test size of 20%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 1, stratify = y)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((227845, 30), (227845,), (56962, 30), (56962,))

# %%
#reshaping and normalizing
#use StandardScaler to standardize data because values are pretty different(some values too high compare to others)
x_train = StandardScaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
